# %%
import pandas as pd
df = pd.read_csv("Sample_data.csv")#Create dataframe from csv file. If not in folder, provide absolute path.
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df = pd.read_excel("Sample_data_2.xls", "Sheet1")#Create dataframe from excel file.
df
# Out:
#   Cell In[16], line 1
#     df = pd.read_excel("C:\Users\HASHIR\Pandas Tutorial\Sample_data_2.xls", "Sheet1")#Create dataframe from excel file.
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data = {
    "Employee_ID": [1001, 1002, 1003, 1004, 1005],
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma"],
    "Age": [25, 30, 22, 28, 27],
    "Department": ["HR", "IT", "Finance", "Marketing", "Sales"],
    "Salary": [50000, 60000, 55000, 58000, 62000],
    "Joining_Date": ["2020-05-21", "2019-08-15", "2021-02-10", "2018-12-05", "2022-01-20"]
}
df = pd.DataFrame(data)
df
# Out:
#    Employee_ID     Name  Age Department  Salary Joining_Date
# 0         1001    Alice   25         HR   50000   2020-05-21
# 1         1002      Bob   30         IT   60000   2019-08-15
# 2         1003  Charlie   22    Finance   55000   2021-02-10
# 3         1004    David   28  Marketing   58000   2018-12-05
# 4         1005     Emma   27      Sales   62000   2022-01-20

# %%
data = [
    (1001, "Alice", 25, "HR", 50000, "2020-05-21"),
    (1002, "Bob", 30, "IT", 60000, "2019-08-15"),
    (1003, "Charlie", 22, "Finance", 55000, "2021-02-10"),
    (1004, "David", 28, "Marketing", 58000, "2018-12-05"),
    (1005, "Emma", 27, "Sales", 62000, "2022-01-20"),
]
df = pd.DataFrame(data, columns = ["Employee_ID", "Name", "Age", "Department", "Salary", "Joining_Date"])
df
# Out:
#    Employee_ID     Name  Age Department  Salary Joining_Date
# 0         1001    Alice   25         HR   50000   2020-05-21
# 1         1002      Bob   30         IT   60000   2019-08-15
# 2         1003  Charlie   22    Finance   55000   2021-02-10
# 3         1004    David   28  Marketing   58000   2018-12-05
# 4         1005     Emma   27      Sales   62000   2022-01-20

# %%
data = [
    {"Employee_ID": 1001, "Name": "Alice", "Age": 25, "Department": "HR", "Salary": 50000, "Joining_Date": "2020-05-21"},
    {"Employee_ID": 1002, "Name": "Bob", "Age": 30, "Department": "IT", "Salary": 60000, "Joining_Date": "2019-08-15"},
    {"Employee_ID": 1003, "Name": "Charlie", "Age": 22, "Department": "Finance", "Salary": 55000, "Joining_Date": "2021-02-10"},
    {"Employee_ID": 1004, "Name": "David", "Age": 28, "Department": "Marketing", "Salary": 58000, "Joining_Date": "2018-12-05"},
    {"Employee_ID": 1005, "Name": "Emma", "Age": 27, "Department": "Sales", "Salary": 62000, "Joining_Date": "2022-01-20"},
]
df = pd.DataFrame(data)
df
# Out:
#    Employee_ID     Name  Age Department  Salary Joining_Date
# 0         1001    Alice   25         HR   50000   2020-05-21
# 1         1002      Bob   30         IT   60000   2019-08-15
# 2         1003  Charlie   22    Finance   55000   2021-02-10
# 3         1004    David   28  Marketing   58000   2018-12-05
# 4         1005     Emma   27      Sales   62000   2022-01-20
